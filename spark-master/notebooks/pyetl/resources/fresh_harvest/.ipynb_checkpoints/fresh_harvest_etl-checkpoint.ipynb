# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float, DateTime, ForeignKey, func
from sqlalchemy.orm import sessionmaker
import matplotlib.pyplot as plt
import mlflow
import mooncake

# %% [markdown]
# # Utils

# %%
def normalize_str_columns(df, columns=None, lower=True, copy=True, trunc=None):
    """For each column in ``columns``, the following operations are applied:
    
    - NFKD unicode normalzation
    - ascii encoding
    - utf-8 decoding
    
    Parameters
    ----------
    df : pd.DataFrame
    
    columns : list of str, default=None
        List of columns to normalize. If None, all 'object' dtype columns
        are used.
    
    lower : bool, default=True
    
    copy : bool, default=True
    
    trunc: int, default=None
        If not None, truncates str columns to the given int.
    """
    if copy:
        df = df.copy()
    if columns is None:
        columns = df.select_dtypes('object').columns.tolist()
        
    def str_normalization(x):
        x = x.str.normalize('NFKD')
        x = x.str.encode('ascii', errors='ignore')
        x = x.str.decode('utf-8')
        if lower:
            x = x.str.lower()
        if trunc is not None:
            x = x.str.slice(0, trunc)
        return x
    
    df[columns] = df[columns].apply(str_normalization)
    return df

def create_dim(fact_table, columns, rename=None):
    """Creates dimensional table from fact table.
    
    Parameters
    ----------
    fact_table : pd.DataFrame
    
    columns : list of str.
        Columns used for dimensional table.
        
    rename : dict, str -> str
        Dictionary for renaming dimensional columns.
    """
    grouper = fact_table.groupby(columns).grouper
    dim = grouper.result_index.to_frame(index=False)
    if rename:
        dim.rename(columns=rename, inplace=True)
    return dim

def encode_relations(df, column_to_table, con, column_to_field=None, id_suffix=False, copy=True):
    """Encodes relationship columns.
    
    Parameters
    ----------
    df : pd.DataFrame
    
    column_to_table : dict, str -> class
        Dict containing the relationships to be encoded.
        E.g., {'product_line': ProductLine} means that the 
        'product_line' column inside ``df`` will be encoded with
        the primary key from the table ``ProductLine`` via an inner join
        with the 'name' field, i.e., ProductLine.name.

        If a field different from 'name' needs to be used, it must be passed
        using the ``column_to_field`` param.
    """
    if copy:
        df = df.copy()
    if column_to_field is None:
        column_to_field = {}

    for column, table in column_to_table.items():
        table_df = pd.read_sql(
            sql=session.query(table).statement, 
            con=con
        )
        if column in column_to_field:
            table_field = column_to_field[column]
        else:
            table_field ='name'
            
        map_ = dict(zip(table_df[table_field], table_df.id))
        df[column] = df[column].map(map_)
    
    if id_suffix:
        rename = {column: column + '_id' for column in column_to_table}
        df.rename(columns=rename, inplace=True)
            
    return df

# %% [markdown]
# # Schema

# %%
# In general the connection str is: dialect+driver://username:password@host:port/database
# Note: The PostgreSQL dialect uses psycopg2 as the default DBAPI
# Note: The host is the name of the database service in docker-compose (postgres)
engine = create_engine('postgresql://postgres:admin@postgres/postgres', echo=True)
Base = declarative_base(bind=engine)
Session = sessionmaker(bind=engine)
session = Session()


class ProductLine(Base):
    __tablename__ = 'product_line'
    id = Column(Integer, primary_key=True, autoincrement=True)
    name = Column(String(50))
    
class Product(Base):
    __tablename__ = 'product'
    id = Column(Integer, primary_key=True, autoincrement=True)
    product_line_id = Column(Integer, ForeignKey('product_line.id'))
    name = Column(String(50))
    
class City(Base):
    __tablename__ = 'city'
    id = Column(Integer, primary_key=True, autoincrement=True)
    name = Column(String(50))
    
class Client(Base):
    __tablename__ = 'client'
    id = Column(Integer, primary_key=True, autoincrement=True)
    city_id = Column(Integer, ForeignKey('city.id'))
    name = Column(String(50))
    
class WorkForce(Base):
    __tablename__ = 'work_force'
    id = Column(Integer, primary_key=True, autoincrement=True)
    name = Column(String(50))
    
class FactTable(Base):
    __tablename__ = 'fact_table'
    id = Column(Integer, primary_key=True, autoincrement=True)
    product_id = Column(Integer, ForeignKey('product.id'))
    client_id = Column(Integer, ForeignKey('client.id'))
    work_force_id = Column(Integer, ForeignKey('work_force.id'))
    date = Column(DateTime)
    money = Column(Float)
    quantity = Column(Float)
    
#Base.metadata.create_all()

# %% [markdown]
# # Insert data

# %%
# Load fact_table from csv
fact_table = pd.read_csv('ventas_2021.csv')

# Keep only database columns and rename them
columns_rename = {
    'Cliente': 'client',
    'Fecha del pedido': 'date',
    'Vendedor': 'work_force',
    'Importe total del pedido': 'money',
    'Cantidad': 'quantity',
    'productos': 'product',
    'Linea de productos': 'product_line',
    'Ciudad (facturación)': 'city'
}
fact_table = fact_table[list(columns_rename)].rename(columns=columns_rename)

# Some preprocessing:
# normalize str columns and truncate them to 50 char
str_columns = ['client', 'work_force', 'product', 'product_line', 'city']
fact_table = normalize_str_columns(fact_table, str_columns, trunc=50)

# fill product_line nans with first word from product column
fact_table.loc[
    fact_table['product_line'].isna(), 
    'product_line'
] = fact_table.loc[
    fact_table['product_line'].isna(),
    'product'
].str.split(' ').str.get(0)

# %%
# Product line dim

product_line_dim = create_dim(
    fact_table, 
    columns=['product_line'], 
    rename={'product_line': 'name'}
)
product_line_dim.to_sql(
    name='product_line',
    con=engine,
    index_label='id',
    if_exists='append'
)
# Out:
# 2022-01-05 23:07:11,874 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-01-05 23:07:11,874 INFO sqlalchemy.engine.Engine [cached since 5.358s ago] {'name': 'product_line'}
# 2022-01-05 23:07:11,876 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-01-05 23:07:11,877 INFO sqlalchemy.engine.Engine INSERT INTO product_line (id, name) VALUES (%(id)s, %(name)s)
# 2022-01-05 23:07:11,877 INFO sqlalchemy.engine.Engine [generated in 0.00042s] ({'id': 0, 'name': 'caja'}, {'id': 1, 'name': 'chamoy'}, {'id': 2, 'name': 'chiles a granel'}, {'id': 3, 'name': 'chiles envasados'}, {'id': 4, 'name': 'cocina gourmet'}, {'id': 5, 'name': 'mango deshidratado'}, {'id': 6, 'name': 'paquetes'}, {'id': 7, 'name': 'salsas'})
# 2022-01-05 23:07:11,879 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Product dim

product_dim = create_dim(
    fact_table,
    columns=['product', 'product_line'],
    rename={'product': 'name'}
)

product_dim = encode_relations(
    product_dim,  
    column_to_table={'product_line': ProductLine}, 
    con=engine,
    id_suffix=True
)

product_dim.to_sql(
    name='product',
    con=engine,
    index_label='id',
    if_exists='append'
)
# Out:
# 2022-01-05 23:07:15,144 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-01-05 23:07:15,145 INFO sqlalchemy.engine.Engine [cached since 8.628s ago] {'name': 'SELECT product_line.id, product_line.name \nFROM product_line'}
# 2022-01-05 23:07:15,149 INFO sqlalchemy.engine.Engine SELECT product_line.id, product_line.name
# FROM product_line
# 2022-01-05 23:07:15,149 INFO sqlalchemy.engine.Engine [generated in 0.00068s] {}
# 2022-01-05 23:07:15,155 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-01-05 23:07:15,156 INFO sqlalchemy.engine.Engine [cached since 8.64s ago] {'name': 'product'}
# 2022-01-05 23:07:15,159 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# ...

# %%
# City dim

city_dim = create_dim(
    fact_table, 
    columns=['city'], 
    rename={'city': 'name'}
)
city_dim.to_sql(
    name='city',
    con=engine,
    index_label='id',
    if_exists='append'
)
# Out:
# 2022-01-05 23:07:15,562 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-01-05 23:07:15,564 INFO sqlalchemy.engine.Engine [cached since 9.047s ago] {'name': 'city'}
# 2022-01-05 23:07:15,568 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-01-05 23:07:15,571 INFO sqlalchemy.engine.Engine INSERT INTO city (id, name) VALUES (%(id)s, %(name)s)
# 2022-01-05 23:07:15,571 INFO sqlalchemy.engine.Engine [generated in 0.00156s] ({'id': 0, 'name': '..'}, {'id': 1, 'name': '3 hermanos'}, {'id': 2, 'name': 'acuario'}, {'id': 3, 'name': 'agua marina # 56 int. 101 fracc. villa esmeralda'}, {'id': 4, 'name': 'aguascalientes'}, {'id': 5, 'name': 'ajijic'}, {'id': 6, 'name': 'ajijic , jalisco'}, {'id': 7, 'name': 'ajijic, jalisco'}  ... displaying 10 of 333 total bound parameter sets ...  {'id': 331, 'name': 'zapopan jalisco'}, {'id': 332, 'name': 'zapopan, jalisco'})
# ...

# %%
# Client dim

client_dim = create_dim(
    fact_table,
    columns=['client', 'city'],
    rename={'client': 'name'}
)

client_dim = encode_relations(
    client_dim,  
    column_to_table={'city': City}, 
    con=engine,
    id_suffix=True
)

client_dim.to_sql(
    name='client',
    con=engine,
    index_label='id',
    if_exists='append'
)
# Out:
# 2022-01-05 23:07:16,007 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-01-05 23:07:16,008 INFO sqlalchemy.engine.Engine [cached since 9.492s ago] {'name': 'SELECT city.id, city.name \nFROM city'}
# 2022-01-05 23:07:16,010 INFO sqlalchemy.engine.Engine SELECT city.id, city.name
# FROM city
# 2022-01-05 23:07:16,011 INFO sqlalchemy.engine.Engine [generated in 0.00090s] {}
# 2022-01-05 23:07:16,018 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-01-05 23:07:16,019 INFO sqlalchemy.engine.Engine [cached since 9.502s ago] {'name': 'client'}
# 2022-01-05 23:07:16,022 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# ...

# %%
# Work force dim

work_force_dim = create_dim(
    fact_table, 
    columns=['work_force'], 
    rename={'work_force': 'name'}
)
work_force_dim.to_sql(
    name='work_force',
    con=engine,
    index_label='id',
    if_exists='append'
)
# Out:
# 2022-01-05 23:07:16,424 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-01-05 23:07:16,425 INFO sqlalchemy.engine.Engine [cached since 9.909s ago] {'name': 'work_force'}
# 2022-01-05 23:07:16,430 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-01-05 23:07:16,432 INFO sqlalchemy.engine.Engine INSERT INTO work_force (id, name) VALUES (%(id)s, %(name)s)
# 2022-01-05 23:07:16,433 INFO sqlalchemy.engine.Engine [generated in 0.00107s] ({'id': 0, 'name': 'abran gallegos'}, {'id': 1, 'name': 'alex flores'}, {'id': 2, 'name': 'alexi yermaid'}, {'id': 3, 'name': 'almara ibarra'}, {'id': 4, 'name': 'amairani sepulveda'}, {'id': 5, 'name': 'antonio reyes'}, {'id': 6, 'name': 'armando arcega'}, {'id': 7, 'name': 'briat sanchez lopez'}  ... displaying 10 of 34 total bound parameter sets ...  {'id': 32, 'name': 'saul beltran'}, {'id': 33, 'name': 'viviana aznar'})
# ...

# %%
# Fact table encoding

column_to_table = {
    'client': Client,
    'work_force': WorkForce,
    'product': Product
}
cols_to_keep = [col + '_id' for col in column_to_table] + ['date', 'quantity', 'money']
encoded_fact_table = encode_relations(
    fact_table,
    column_to_table=column_to_table,
    id_suffix=True,
    con=engine
)[cols_to_keep]
encoded_fact_table['date'] = pd.to_datetime(encoded_fact_table['date'])

encoded_fact_table.to_sql(
    name='fact_table',
    con=engine,
    index_label='id',
    if_exists='append'
)
# Out:
# 2022-01-05 23:07:16,869 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-01-05 23:07:16,870 INFO sqlalchemy.engine.Engine [cached since 10.35s ago] {'name': 'SELECT client.id, client.city_id, client.name \nFROM client'}
# 2022-01-05 23:07:16,875 INFO sqlalchemy.engine.Engine SELECT client.id, client.city_id, client.name
# FROM client
# 2022-01-05 23:07:16,876 INFO sqlalchemy.engine.Engine [generated in 0.00122s] {}
# 2022-01-05 23:07:16,914 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-01-05 23:07:16,915 INFO sqlalchemy.engine.Engine [cached since 10.4s ago] {'name': 'SELECT work_force.id, work_force.name \nFROM work_force'}
# 2022-01-05 23:07:16,917 INFO sqlalchemy.engine.Engine SELECT work_force.id, work_force.name
# ...

# %% [markdown]
# # Query fact table

# %%
def get_product_sales(con, product_ids, client_ids=None):
    query = session.query(
        FactTable.product_id,
        FactTable.date,
        func.sum(FactTable.money).label('money'),
        func.sum(FactTable.quantity).label('quantity'),
    ).filter(FactTable.product_id.in_(product_ids))
    
    if client_ids is not None:
        query = query.filter(FactTable.client_id.in_(client_ids))
        
    query = query.group_by(FactTable.product_id, FactTable.date)
    return pd.read_sql(
        sql=query.statement,
        con=con
    )

# %%
product_ids = [75, 27, 28]
df_sales = get_product_sales(engine, product_ids)
# Out:
# 2022-01-11 00:09:35,535 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2022-01-11 00:09:35,536 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-01-11 00:09:35,539 INFO sqlalchemy.engine.Engine select current_schema()
# 2022-01-11 00:09:35,540 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-01-11 00:09:35,541 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2022-01-11 00:09:35,542 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-01-11 00:09:35,546 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-01-11 00:09:35,547 INFO sqlalchemy.engine.Engine [generated in 0.00054s] {'name': 'SELECT fact_table.product_id, fact_table.date, sum(fact_table.money) AS money, sum(fact_table.quantity) AS quantity \nFROM fact_table \nWHERE fact_table.product_id IN (__[POSTCOMPILE_product_id_1]) GROUP BY fact_table.product_id, fact_table.date'}
# ...

# %%
df_sales_resample = df_sales.set_index('date'
                                      ).groupby('product_id'
                                      ).resample('D'
                                      ).agg({'money': sum, 'quantity': sum}
                                      ).reset_index()

groupby = df_sales_resample.groupby('product_id')
fig, axs = plt.subplots(len(groupby), 1, figsize=(15, 15))
for i, g in enumerate(groupby.groups):
    ax = axs[i]
    group = groupby.get_group(g).copy()
    group['price'] = group['money'] / group['quantity']
    group.set_index('date')[['quantity', 'price']].plot(secondary_y='price', ax=ax)

# %% [markdown]
# # Fit model

# %%
from mooncake.nn import SeqToSeq
from mooncake.model_selection import train_test_split
from mooncake.preprocessing import (
    GroupTransformer, 
    TimeIndex, 
    CyclicalDates, 
    DataframeColumnTransformer
)
from mooncake.helper import column_selector, common_callbacks
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from torch.optim.lr_scheduler import OneCycleLR

# %%
# Define X

product_ids = [75, 27, 28]
freq = 'D'
date = 'date'
group_ids = ['product_id']
target = 'quantity'
X = get_product_sales(engine, product_ids)
X = X.set_index(date
               ).groupby(group_ids
               ).resample(freq
               ).agg({'money': sum, 'quantity': sum}
               ).reset_index()
X.head()  # inspect X
# Out:
# 2022-01-11 00:13:44,709 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-01-11 00:13:44,710 INFO sqlalchemy.engine.Engine [cached since 249.2s ago] {'name': 'SELECT fact_table.product_id, fact_table.date, sum(fact_table.money) AS money, sum(fact_table.quantity) AS quantity \nFROM fact_table \nWHERE fact_table.product_id IN (__[POSTCOMPILE_product_id_1]) GROUP BY fact_table.product_id, fact_table.date'}
# 2022-01-11 00:13:44,715 INFO sqlalchemy.engine.Engine SELECT fact_table.product_id, fact_table.date, sum(fact_table.money) AS money, sum(fact_table.quantity) AS quantity
# FROM fact_table
# WHERE fact_table.product_id IN (%(product_id_1_1)s, %(product_id_1_2)s, %(product_id_1_3)s) GROUP BY fact_table.product_id, fact_table.date
# ...

# %%
# Suppose we want to forecast the selected products from '2021-08-01' to '2021-10-01' (two months)

# Forecast period
test_start = '2021-09-01'
test_end = '2021-10-01'

# Sequence lengths
prediction_length = len(pd.date_range(test_start, test_end, freq=freq))
max_encoder_length = 2 * prediction_length
min_encoder_length = prediction_length

# Transform date column to time index
X['time_idx'] = X[date].copy()
time_idx_transformer = GroupTransformer(
    transformers=[('time_idx', TimeIndex(), 'time_idx')],
    group_ids=group_ids
)
X = time_idx_transformer.fit_transform(X)

# Add price column
X['price'] = X['money'] / X['quantity']
X.loc[X['price'].isna(), 'price'] = 0
del X['money']

# Change group_ids dtype
for g in group_ids:
    X[g] = X[g].astype(str)

# Train-test split 
X_train, X_test = train_test_split(
    X=X,
    test_start=test_start,
    test_end=test_end,
    date_column=date,
    freq=freq,
    sequence_length=max_encoder_length
)

X_train.head()  # inspect X_train
# Out:
#    time_idx product_id       date  quantity       price
# 0         0         27 2021-01-01     144.0   61.944444
# 1         1         27 2021-01-02       6.0  141.333333
# 2         2         27 2021-01-03       4.0  193.750000
# 3         3         27 2021-01-04      50.0  211.380000
# 4         4         27 2021-01-05     228.0  106.140351

# %%
def get_columns_segmentation(X, target, group_ids, time_idx):
    """Segments columns in three types:

    - time_varying_known_reals
        These include all numerical columns except ``target``, ``group_ids``
        and ``time idx``.

    - time_varying_unknown_reals
        Only includes ``target``

    - static_categoricals
        These include all 'object' dtype columns

    Returns
    -------
    dict : str -> list
    """
    from mooncake.helper import column_selector
    time_varying_known_reals = column_selector(
        dtype_include=[int, float],
        pattern_exclude=[target, time_idx] + group_ids
    )(X)
    time_varying_unknown_reals = [target]
    static_categoricals = column_selector(dtype_include=['object'])(X)
    return {
        'time_varying_known_reals': time_varying_known_reals,
        'time_varying_unknown_reals': time_varying_unknown_reals,
        'static_categoricals': static_categoricals
    }

def get_history(estimator, name):
    """Obtains history from estimator

    A history is any collection values recorded during training under a
    given name. Histories can be error metrics, loss functions, flags, etc

    For any fitted bluemeth estimator, histories are stored inside the
    `history` attribute inside the skorch model, e.g., estimator.net_.history.

    Parameters
    ----------
    estimator : bluemeth estimator
        Fitted blue meth estimator

    name : str
        Name of the history

    Returns
    -------
    history : list
    """
    if hasattr(estimator, 'estimators'):
        # Collect history in all estimators
        histories = []
        for est in estimator.estimators:
            histories.append(est.net_.history[:, name])

        # Get max length
        max_length = max(len(x) for x in histories)

        # Pad each history with nans at the end
        padded_histories = []
        for hist in histories:
            pad_hist = np.pad(
                hist,
                (0, max_length - len(hist)),
                constant_values=np.nan
            )
            padded_histories.append(pad_hist)

        # Return mean of all histories
        avg_histories = np.nanmean(padded_histories, axis=0)
        return avg_histories

    history = estimator.net_.history[:, name]
    return history

def log_array(key, array):
    """Logs array to current mlflow run

    Parameters
    ----------
    key : str
        Metric name

    array : array_like
        Collection of values to be log
    """
    for i, value in enumerate(array):
        mlflow.log_metric(key=key, value=value, step=i)

# %%
# Preprocessing

# inner
selector = column_selector(
    dtype_include=['float', 'int'],
    pattern_exclude=group_ids + ['time_idx']
)
group_transformers = [
    ('cont', MinMaxScaler(), selector)
]

# outer
outer_transformers = [
    ('cyclical_dates', CyclicalDates(dayofweek=True, month=False), date)
]

# preprocessor pipeline
steps = [
    ('inner', GroupTransformer(group_transformers, group_ids)),
    ('outer', DataframeColumnTransformer(outer_transformers))
]
preprocessor = Pipeline(steps=steps)
X_train_transformed = preprocessor.fit_transform(X_train)

# %%
# Fit

# column segmentation
column_segmentation = get_columns_segmentation(
    X_train_transformed, 
    target=target, 
    group_ids=group_ids, 
    time_idx='time_idx'
)

# callbacks
lr_scheduler = {
    'policy': OneCycleLR,
    'step_every': 'batch',
    'max_lr': 1e-3,
    'steps_per_epoch': 'iterations',
    'epochs': 'max_epochs'
}
callbacks = common_callbacks(
    lr_scheduler, 
    gradient_clipping=True,
    early_stopping=True, 
    patience=50
)


# model instance
estimator = SeqToSeq(
    group_ids=group_ids,
    time_idx='time_idx',
    target=target,
    max_prediction_length=prediction_length,
    max_encoder_length=max_encoder_length,
    min_encoder_length=min_encoder_length,
    callbacks=callbacks,
    emb_dim=50,
    tf_ratio=0.1,
    batch_size=16,
    max_epochs=100,
    hidden_size=32,
    **column_segmentation
)
try:
    # Try to pass test data as validation
    X_test_transformed = preprocessor.transform(X_test)
    ds_test = estimator.get_dataset(X_test_transformed)
    estimator.cv_split = ds_test
except (AssertionError, ValueError):
    # Here, we assume the reason ``X_test`` couldn't be transformed
    # to a dataset was because the target column contains NaN values.
    X_test[target] = X_test[target].fillna(0)

# %%
# training

estimator.fit(X_train_transformed)
# Out:
#   epoch    train_loss    valid_loss     dur
# -------  ------------  ------------  ------
#       1        0.2921        0.2753  0.5990
#       2        0.2779        0.2596  0.5884
#       3        0.2625        0.2411  0.5882
#       4        0.2442        0.2183  0.5868
#       5        0.2212        0.1892  0.6022
#       6        0.1930        0.1518  0.5923
#       7        0.1598        0.1119  0.6064
#       8        0.1395        0.1035  0.6083
#       9        0.1378        0.1006  0.6014
#      10        0.1364        0.1001  0.5978
#      11        0.1366        0.0996  0.5997
#      12        0.1358        0.0988  0.5844
#      13        0.1345        0.0988  0.5882
#      14        0.1340        0.0982  0.5944
#      15        0.1340        0.0975  0.5817
#      16        0.1336        0.0975  0.5881
#      17        0.1332        0.0972  0.5983
#      18        0.1324        0.0958  0.5812
#      19        0.1321        0.0955  0.6018
# ...

# %%
# Log to mflow

# create experiment
with mlflow.start_run():

    # log preprocessor and estimator in a pipeline format
    steps = [('preprocessor', preprocessor), ('estimator', estimator)]
    pipe = Pipeline(steps=steps)
    mlflow.sklearn.log_model(pipe, 'pipe')

    # log estimator params
    params = estimator.get_params()
    params = {k: v for k, v in params.items()
              if k not in column_segmentation and k not in
              ('callbacks', 'callbacks_')}
    mlflow.log_params(params)

    # log losses
    train_loss = get_history(estimator, 'train_loss')
    valid_loss = get_history(estimator, 'valid_loss')
    log_array('train_loss', train_loss)
    log_array('valid_loss', valid_loss)

# %%
yhat_train = estimator.predict(
    X_train_transformed, 
    raw=False, 
    inverse_transformer=preprocessor
)
yhat_test = estimator.predict(
    X_test_transformed, 
    raw=False, 
    inverse_transformer=preprocessor
)

groupby_train = yhat_train.groupby(group_ids)
groupby_test = yhat_test.groupby(group_ids)
fig, axs = plt.subplots(len(groupby), 2, figsize=(22, 15))
axs = axs.flatten()
for i, g in enumerate(groupby.groups):
    g = str(g)
    ax_l = axs[2 * i]
    ax_r = axs[2 * i + 1]
    
    groupby_train.get_group(g).set_index('time_idx').plot(ax=ax_l)
    groupby_test.get_group(g).set_index('time_idx').plot(ax=ax_r)
